# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Set the path to the image file
#image_path = add imag path 

# Load and display the image
img = mpimg.imread(image_path)
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()
